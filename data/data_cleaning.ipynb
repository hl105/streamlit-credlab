# %% [markdown]
# convert candidate's json file into csv

# %%
import json
import csv
import os
import pandas as pd

json_file_name = os.path.join(os.getcwd(),'candidates-stories','Bernie Sanders.json')
df = pd.read_json(json_file_name)
df
# Out:
#                                                    title  \
# 0      Iowa Poll: Biden, Sanders top early look at po...
# 1      Just Messing: Twitter outrage at Bernie Sander...
# 2      Biden, Sanders top potential 2020 Democratic n...
# 3      Iowa Poll: First poll of likely caucusgoers fi...
# 4      Biden Leads Sanders, O'Rourke in Iowa Democrat...
# ...                                                  ...
# 28655  3 Months After Heart Attack, Sanders' Doctors ...
# 28656  Sanders releases letters from 3 doctors attest...
# 28657  Sanders releases doctors’ letters saying he’s ...
# 28658  Bernie Sanders is in ‘good health’ after heart...
# 28659  #PresidentSanders Trends As Vermont Senator Re...
#
#                                                      url               source  \
# 0      https://www.desmoinesregister.com/story/news/p...  Des Moines Register
# 1      https://www.rt.com/usa/446563-messing-compares...               RT.com
# ...

# %%
print("shape",df.shape)
df['story_position'].describe()
# Out:
# shape (28660, 11)
# count    28495.000000
# mean         5.490577
# std          2.874344
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          8.000000
# max         10.000000
# Name: story_position, dtype: float64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date'].max().date()
# Out:
# datetime.date(2019, 12, 30)

# %%
"""
want to:
create slider -- user can pick whatever date
10 top stories appear - clickable link to url
"""
